# %%
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36'}

request = requests.get("https://www.amazon.in/s?k=mobile+phone+under+20000&crid=2J6DM5J2AVMGE&sprefix=mobile%2Caps%2C256&ref=nb_sb_ss_ts-doa-p_3_63",headers=headers)
# print(request)
# print(request.content)

# %%
soup = BeautifulSoup(request.content, 'html.parser')
# print(soup.prettify())

products = []

product_elements = soup.select('.s-main-slot .s-result-item')

# %%
for product in product_elements:
    title = product.select_one('h2 a span').get_text(strip=True) if product.select_one('h2 a span') else 'no Title'

    price = product.select_one('.a-price').get_text(strip=True).strip() if product.select_one('.a-price') else 'No price'

    products.append({
        'title': title,
        'price': price
    })

# %%
for product in products:
    print(f"Title: {product['title']} \nPrice: {product['price']}\n\n")
# Out:
# Title: no Title
# Price: ₹15,999₹15,999
#
#
# Title: no Title
# Price: No price
#
#
# Title: OnePlus Nord CE4 Lite 5G (Super Silver, 8GB RAM, 128GB Storage)
# Price: ₹19,998₹19,998
#
#
# Title: Motorola G64 5G (Ice Lilac, 12GB RAM, 256GB Storage) | Expandable Upto 2TB | Upto 24GB RAM with RAM Boost | 50MP (OIS) + 8MP | 16MP Front Camera | MediaTek Dimensity 7025 Processor | 6000 mAh Battery
# Price: ₹17,495₹17,495
#
#
# Title: OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 8GB RAM, 128GB Storage)
# Price: ₹15,999₹15,999
#
#
# Title: Redmi 13 5G, Hawaiian Blue, 6GB+128GB | India Debut SD 4 Gen 2 AE | 108MP Pro Grade Camera | 6.79in Largest Display in Segment
# Price: ₹13,499₹13,499
#
#
# Title: no Title
# Price: No price
#
#
# Title: realme NARZO 70x 5G (Forest Green, 8GB RAM,128GB Storage) | 120Hz Ultra Smooth Display | Dimensity 6100+ 6nm 5G | 50MP AI Camera | 45W Charger in The Box
# Price: ₹13,499₹13,499
#
#
# Title: realme NARZO N61 (Marble Black,6GB RAM+128GB Storage) 90Hz Eye Comfort Display | IP54 Dust & Water Resistance | 48-Month Fluency | Charger in The Box
# Price: ₹8,498₹8,498
#
#
# Title: realme NARZO 70x 5G (Ice Blue, 6GB RAM,128GB Storage)|120Hz Ultra Smooth Display|Dimensity 6100+ 6nm 5G|50MP AI Camera|45W Charger in The Box
# Price: ₹12,499₹12,499
#
#
# Title: Redmi Note 13 5G (Arctic White, 12GB RAM, 256GB Storage) | 5G Ready | 120Hz Bezel-Less AMOLED | 7.mm Slimmest Note Ever | 108MP Pro-Grade Camera
# Price: ₹18,999₹18,999
#
#
# Title: Samsung Galaxy M15 5G Prime Edition (Blue Topaz,6GB RAM,128GB Storage) | Super AMOLED Display| 50MP Triple Cam| 6000mAh Battery| MediaTek Dimensity 6100+ | 4 Gen. OS Upgrade & 5 Year Security Update
# Price: ₹11,999₹11,999
#
#
# Title: Samsung Galaxy M15 5G Prime Edition (Stone Grey,6GB RAM,128GB Storage)| Super AMOLED Display| 50MP Triple Cam| 6000mAh Battery| MediaTek Dimensity 6100+| 4 Gen. OS Upgrade & 5 Year Security Update
# Price: ₹11,999₹11,999
#
#
# Title: no Title
# Price: No price
#
#
# Title: realme 12x 5G (Twilight Purple, 8GB RAM, 128GB Storage) | Upto 16GB (8+8GB) Dynamic RAM | Dimensity 6100+ Processor | 50 MP AI Camera | 7.69 mm Ultra-Slim Trendy Watch Design | 45 W SUPERVOOC Charge
# Price: ₹12,940₹12,940
#
#
# Title: OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 8GB RAM, 256GB Storage)
# Price: ₹19,999₹19,999
#
#
# Title: realme NARZO 70 Turbo 5G (Turbo Yellow,6GB RAM,128GB Storage) | Segment's Fastest Dimensity 7300 Energy 5G Chipset | Motorsports Inspired Design
# Price: ₹16,998₹16,998
#
#
# Title: POCO X6 5G (Snowstorm White, 12 GB RAM 256 GB Storage)
# Price: ₹17,999₹17,999
#
#
# Title: iQOO Z9x 5G (Storm Grey, 8GB RAM, 128GB Storage) | Snapdragon 6 Gen 1 with 560k+ AnTuTu Score | 6000mAh Battery with 7.99mm Slim Design | 44W FlashCharge
# Price: ₹15,499₹15,499
#
#
# Title: Samsung Galaxy M35 5G (Thunder Grey,6GB RAM,128GB Storage)| Corning Gorilla Glass Victus+| AnTuTu Score 595K+ | Vapour Cooling Chamber | 6000mAh Battery | 120Hz Super AMOLED Display| Without Charger
# Price: ₹14,999₹14,999
#
#
# Title: realme NARZO N65 5G (Deep Green 4GB RAM, 128GB Storage) India's 1st D6300 5G Chipset | Ultra Slim 190g Design | 120Hz Eye Comfort Display | 50MP AI Camera| Charger in The Box
# Price: ₹10,499₹10,499
#
#
# Title: no Title
# Price: No price
#
#
# Title: no Title
# Price: No price
#
#
# Title: no Title
# Price: No price
#
#
# Title: no Title
# Price: No price
#
#
# Title: no Title
# Price: No price
